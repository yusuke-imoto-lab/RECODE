# %%
import screcode
import h5py
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import scipy
import pandas as pd
import importlib
importlib.reload(screcode)
# %matplotlib inline

# %%
data_pd = {}
data = {}
data_scRECODE = {}
screc = {}

# %%
machine = '10X'
data_pd[machine] = pd.read_csv('data/210922_HCA_RawUMI/HCA_%s_Hs_RawUMI.csv' % machine, index_col=0)
data[machine] = data_pd[machine].values
print(data[machine].shape)
print(np.mean(np.sum(data[machine],axis=1)))
screc[machine] = screcode.scRECODE()
data_scRECODE[machine] = screc[machine].fit_transform(data[machine])
screc[machine].check_applicability(save=True,save_filename='figure/HCA_%s_Hs_RawUMI_applicability' % machine)
screc[machine].compare_mean_variance_log(save=True,save_filename='figure/HCA_%s_Hs_RawUMI_mean_var_log' % machine)
# Out:
# (1951, 20004)
# 9726.461814454125
# start scRECODE
# end scRECODE
# parameter: {'#significant genes': 11950, '#non-significant genes': 4609, '#silent genes': 3445, 'ell': 52, 'elapsed_time': '14.68[sec]'}

# %%
machine = 'DROP'
data_pd[machine] = pd.read_csv('data/210922_HCA_RawUMI/HCA_%s_Hs_RawUMI.csv' % machine, index_col=0)
data[machine] = data_pd[machine].values
print(data[machine].shape)
print(np.mean(np.sum(data[machine],axis=1)))
screc[machine] = screcode.scRECODE()
data_scRECODE[machine] = screc[machine].fit_transform(data[machine])
screc[machine].check_applicability(save=True,save_filename='figure/HCA_%s_Hs_RawUMI_applicability' % machine)
screc[machine].compare_mean_variance_log(save=True,save_filename='figure/HCA_%s_Hs_RawUMI_mean_var_log' % machine)
# Out:
# (1257, 20017)
# 4545.249005568815
# start scRECODE
# end scRECODE
# parameter: {'#significant genes': 12194, '#non-significant genes': 4519, '#silent genes': 3304, 'ell': 114, 'elapsed_time': '12.9787[sec]'}

# %%
machine = 'Quartz'
data_pd[machine] = pd.read_csv('data/210922_HCA_RawUMI/HCA_%s_Hs_RawUMI.csv' % machine, index_col=0)
data[machine] = data_pd[machine].values
print(data[machine].shape)
print(np.mean(np.sum(data[machine],axis=1)))
screc[machine] = screcode.scRECODE()
data_scRECODE[machine] = screc[machine].fit_transform(data[machine])
screc[machine].check_applicability(save=True,save_filename='figure/HCA_%s_Hs_RawUMI_applicability' % machine)
screc[machine].compare_mean_variance_log(save=True,save_filename='figure/HCA_%s_Hs_RawUMI_mean_var_log' % machine)
# Out:
# (327, 20004)
# 180888.8501529052
# start scRECODE
# end scRECODE
# parameter: {'#significant genes': 15206, '#non-significant genes': 2778, '#silent genes': 2020, 'ell': 68, 'elapsed_time': '3.5879[sec]'}

# %%
machine = 'SS3'
data_pd[machine] = pd.read_csv('data/210922_HCA_RawUMI/HCA_%s_Hs_RawUMI.csv' % machine, index_col=0)
data[machine] = data_pd[machine].values
print(data[machine].shape)
print(np.mean(np.sum(data[machine],axis=1)))
screc[machine] = screcode.scRECODE(acceleration=False)
data_scRECODE[machine] = screc[machine].fit_transform(data[machine])
screc[machine].check_applicability(save=True,save_filename='figure/HCA_%s_Hs_RawUMI_applicability' % machine)
screc[machine].compare_mean_variance_log(save=True,save_filename='figure/HCA_%s_Hs_RawUMI_mean_var_log' % machine)
# Out:
# (3232, 20004)
# 8490.473391089108
# start scRECODE
# end scRECODE
# parameter: {'#significant genes': 16212, '#non-significant genes': 1304, '#silent genes': 2488, 'ell': 1282, 'elapsed_time': '89.4153[sec]'}

# %%
machine = 'SS2'
data_pd[machine] = pd.read_csv('data/210922_HCA_RawUMI/HCA_%s_Hs_RawRC.csv' % machine, index_col=0)
data[machine] = data_pd[machine].values
print(data[machine].shape)
print(np.mean(np.sum(data[machine],axis=1)))
screc[machine] = screcode.scRECODE()
data_scRECODE[machine] = screc[machine].fit_transform(data[machine])
screc[machine].check_applicability(save=True,save_filename='figure/HCA_%s_Hs_RawUMI_applicability' % machine)
screc[machine].compare_mean_variance_log(save=True,save_filename='figure/HCA_%s_Hs_RawUMI_mean_var_log' % machine)
# Out:
# (1120, 20004)
# 29112.045535714286
# start scRECODE
# end scRECODE
# parameter: {'#significant genes': 16279, '#non-significant genes': 1909, '#silent genes': 1816, 'ell': 835, 'elapsed_time': '11.7826[sec]'}

# %%
machine = '10X_CellBench'
data_pd[machine] = pd.read_csv('data/210922_HCA_RawUMI/CellBench_10X_RawUMI.csv', index_col=0)
data[machine] = data_pd[machine].values
print(data[machine].shape)
print(np.mean(np.sum(data[machine],axis=1)))
screc[machine] = screcode.scRECODE()
data_scRECODE[machine] = screc[machine].fit_transform(data[machine])
screc[machine].check_applicability(save=True,save_filename='figure/CellBench_10X_RawUMI_applicability')
screc[machine].compare_mean_variance_log(save=True,save_filename='figure/CellBench_10X_RawUMI_mean_var_log')
# Out:
# (3702, 20004)
# 24152.87817396002
# start scRECODE
# end scRECODE
# parameter: {'#significant genes': 12911, '#non-significant genes': 3818, '#silent genes': 3275, 'ell': 150, 'elapsed_time': '21.7913[sec]'}
