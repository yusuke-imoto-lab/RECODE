# %%
import screcode
import h5py
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import scipy
import pandas as pd
import importlib
importlib.reload(screcode)
# %matplotlib inline

# %%
data_pd = {}
data = {}
data_scRECODE = {}
screc = {}

# %%
machine = '10X'
data_pd[machine] = pd.read_csv('data/210922_HCA_RawUMI/HCA_%s_Hs_RawUMI.csv' % machine, index_col=0)
data[machine] = data_pd[machine].values
print(data[machine].shape)
screc[machine] = screcode.scRECODE()
data_scRECODE[machine] = screc[machine].fit_transform(data[machine])
screc[machine].check_applicability(save=True,save_filename='figure/HCA_%s_Hs_RawUMI_applicability' % machine)
screc[machine].compare_mean_variance_log(save=True,save_filename='figure/HCA_%s_Hs_RawUMI_mean_var_log' % machine)
# Out:
# (1951, 20004)
# start scRECODE
# end scRECODE
# parameter: {'#significant genes': 11950, '#non-significant genes': 4609, '#silent genes': 3445, 'ell': 52, 'elapsed_time': '17.6473[sec]'}

# %%
machine = 'DROP'
data_pd[machine] = pd.read_csv('data/210922_HCA_RawUMI/HCA_%s_Hs_RawUMI.csv' % machine, index_col=0)
data[machine] = data_pd[machine].values
print(data[machine].shape)
screc[machine] = screcode.scRECODE()
data_scRECODE[machine] = screc[machine].fit_transform(data[machine])
screc[machine].check_applicability(save=True,save_filename='figure/HCA_%s_Hs_RawUMI_applicability' % machine)
screc[machine].compare_mean_variance_log(save=True,save_filename='figure/HCA_%s_Hs_RawUMI_mean_var_log' % machine)
# Out:
# (1257, 20017)
# start scRECODE
# end scRECODE
# parameter: {'#significant genes': 12194, '#non-significant genes': 4519, '#silent genes': 3304, 'ell': 114, 'elapsed_time': '13.7278[sec]'}

# %%
import importlib
importlib.reload(screcode)
machine = 'Quartz'
data_pd[machine] = pd.read_csv('data/210922_HCA_RawUMI/HCA_%s_Hs_RawUMI.csv' % machine, index_col=0)
data[machine] = data_pd[machine].values
print(data[machine].shape)
screc[machine] = screcode.scRECODE()
data_scRECODE[machine] = screc[machine].fit_transform(data[machine])
screc[machine].check_applicability(save=True,save_filename='figure/HCA_%s_Hs_RawUMI_applicability' % machine)
screc[machine].compare_mean_variance_log(save=True,save_filename='figure/HCA_%s_Hs_RawUMI_mean_var_log' % machine)
# Out:
# (327, 20004)
# start scRECODE
# end scRECODE
# parameter: {'#significant genes': 15206, '#non-significant genes': 2778, '#silent genes': 2020, 'ell': 68, 'elapsed_time': '2.931[sec]'}

# %%
import importlib
importlib.reload(screcode)
machine = 'Quartz'
screc[machine] = screcode.scRECODE()
data_scRECODE[machine] = screc[machine].fit(data[machine])
screc[machine].check_applicability(save=True,save_filename='figure/HCA_%s_Hs_RawUMI_applicability' % machine)

# %%
machine = 'SS3'
data_pd[machine] = pd.read_csv('data/210922_HCA_RawUMI/HCA_%s_Hs_RawUMI.csv' % machine, index_col=0)
data[machine] = data_pd[machine].values
print(data[machine].shape)
screc[machine] = screcode.scRECODE(acceleration=False)
data_scRECODE[machine] = screc[machine].fit_transform(data[machine])
screc[machine].check_applicability(save=True,save_filename='figure/HCA_%s_Hs_RawUMI_applicability' % machine)
screc[machine].compare_mean_variance_log(save=True,save_filename='figure/HCA_%s_Hs_RawUMI_mean_var_log' % machine)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-6ea0f151d95d> in <module>
#       1 machine = 'SS3'
# ----> 2 data_pd[machine] = pd.read_csv('data/210922_HCA_RawUMI/HCA_%s_Hs_RawUMI.csv' % machine, index_col=0)
#       3 data[machine] = data_pd[machine].values
#       4 print(data[machine].shape)
#       5 screc[machine] = screcode.scRECODE(acceleration=False)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     603     kwds.update(kwds_defaults)
#     604
# --> 605     return _read(filepath_or_buffer, kwds)
#     606
#     607
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     461
#     462     with parser:
# --> 463         return parser.read(nrows)
#     464
#     465
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in read(self, nrows)
#    1050     def read(self, nrows=None):
#    1051         nrows = validate_integer("nrows", nrows)
# -> 1052         index, columns, col_dict = self._engine.read(nrows)
#    1053
#    1054         if index is None:
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in read(self, nrows)
#    2054     def read(self, nrows=None):
#    2055         try:
# -> 2056             data = self._reader.read(nrows)
#    2057         except StopIteration:
#    2058             if self._first_chunk:
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.read()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._read_low_memory()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._read_rows()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_column_data()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_tokens()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_with_dtype()
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/dtypes/common.py in is_categorical_dtype(arr_or_dtype)
#     535
#     536
# --> 537 def is_categorical_dtype(arr_or_dtype) -> bool:
#     538     """
#     539     Check whether an array-like or dtype is of the Categorical dtype.
#
# KeyboardInterrupt:

# %%
machine = 'SS2'
data_pd[machine] = pd.read_csv('data/210922_HCA_RawUMI/HCA_%s_Hs_RawRC.csv' % machine, index_col=0)
data[machine] = data_pd[machine].values
print(data[machine].shape)
screc[machine] = screcode.scRECODE()
data_scRECODE[machine] = screc[machine].fit_transform(data[machine])
screc[machine].check_applicability(save=True,save_filename='figure/HCA_%s_Hs_RawUMI_applicability' % machine)
screc[machine].compare_mean_variance_log(save=True,save_filename='figure/HCA_%s_Hs_RawUMI_mean_var_log' % machine)

# %%
machine = '10X_CellBench'
data_pd[machine] = pd.read_csv('data/210922_HCA_RawUMI/CellBench_10X_RawUMI.csv', index_col=0)
data[machine] = data_pd[machine].values
print(data[machine].shape)
screc[machine] = screcode.scRECODE()
data_scRECODE[machine] = screc[machine].fit_transform(data[machine])
screc[machine].check_applicability(save=True,save_filename='figure/CellBench_10X_RawUMI_applicability')
screc[machine].compare_mean_variance_log(save=True,save_filename='figure/CellBench_10X_RawUMI_mean_var_log')
